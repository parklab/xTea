# %%
df2 <- read.csv("/n/data1/hms/dbmi/park/simon_chu/projects/XTEA/genotyping/training_set_SSC/Genotyping/feature_importance.csv", header = T, sep = ",")
df2
library(ggplot2)
p2 <- ggplot(df2, aes(x = reorder(Feature, Importance), y = Importance)) +
        geom_bar(stat = "identity") +
        coord_flip() +
        ylab("Feature Importance") + 
        xlab("Features")+
theme(text = element_text(size=15))+
geom_text(aes(label = Importance))
        #ggtitle("Fig. B: Rotated ordered x-axis")
p2
# Out:
#    Feature             Importance
# 1  left-clip-cns       0.020335881
# 2  right-clip-cns      0.016268094
# 3  left-disc-cns       0.020555864
# 4  right-disc-cns      0.044836359
# 5  left-polyA          0.001302112
# 6  right-polyA         0.001517580
# 7  left-local-cov      0.010183352
# 8  right-local-cov     0.007395900
# 9  num-clip            0.068260311
# 10 num-fully-map       0.143855389
# 11 left-raw-clip       0.007527012
# 12 right-raw-clip      0.007412678
# 13 num-discordant-pair 0.289369972
# 14 num-concordant-pair 0.361179497
# plot without title

# %%
library(dplyr)
library(ggplot2)
df2 <- read.csv("feature_importance.csv", header = T, sep = ",")
df2
